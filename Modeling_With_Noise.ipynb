# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense # creates densely connected layer object
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array

from tensorflow import keras
from tensorflow.keras import datasets, layers, models

from tensorflow.keras.layers import Conv2D # convolution layer
from tensorflow.keras.layers import MaxPooling2D # max pooling layer

from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'Data/train_mel_spect_and_noise'

test_dir = 'Data/test_mel_spect'

# %%
train_data_gen_7 = ImageDataGenerator(rescale = 1./255, validation_split = .15)

train_generator_7 = train_data_gen_7.flow_from_directory(

                                                    train_dir, 
                                                    target_size = (200, 150),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'training',)

val_data_gen_7 = ImageDataGenerator(rescale=1./255)

validation_generator_7 = train_data_gen_7.flow_from_directory(
    
                                                    train_dir, 
                                                    target_size = (200, 150),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'validation',)

test_data_gen_7 = ImageDataGenerator(rescale=1./255)

test_generator_7 = test_data_gen_7.flow_from_directory(

                                                    test_dir, 
                                                    target_size = (200, 150),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    shuffle = False)
# Out:
# Found 12619 images belonging to 10 classes.
# Found 2225 images belonging to 10 classes.
# Found 1310 images belonging to 10 classes.

# %%
custom_early_stopping = EarlyStopping(monitor='val_accuracy', patience=5) 
callbacks=[custom_early_stopping]

# %%
model7 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model7.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(200, 150, 3), kernel_regularizer = l2(5e-4) ))

# max pool in 2x2 window
model7.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model7.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-3)))
model7.add(MaxPooling2D((2, 2)))

model7.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(7e-3)))
model7.add(Dropout(0.25))

# transition to dense fully-connected part of network
model7.add(Flatten())
model7.add(Dense(128, activation='relu'))
model7.add(Dropout(0.5))

model7.add(BatchNormalization())
model7.add(Dense(64, activation='relu'))
model7.add(Dropout(0.7))

model7.add(Dense(10, activation='softmax'))

model7.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])`

# %%
history_cnn_7 = model7.fit(train_generator_7, validation_data = validation_generator_7, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 395/395 [==============================] - 131s 330ms/step - loss: 2.5097 - accuracy: 0.1710 - val_loss: 2.2191 - val_accuracy: 0.1892
# Epoch 2/45
# 395/395 [==============================] - 131s 332ms/step - loss: 2.1041 - accuracy: 0.2308 - val_loss: 3.1375 - val_accuracy: 0.1240
# Epoch 3/45
# 395/395 [==============================] - 125s 316ms/step - loss: 2.0661 - accuracy: 0.2447 - val_loss: 2.0544 - val_accuracy: 0.2472
# Epoch 4/45
# 395/395 [==============================] - 134s 339ms/step - loss: 1.9919 - accuracy: 0.2778 - val_loss: 2.0606 - val_accuracy: 0.2440
# Epoch 5/45
# 291/395 [=====================>........] - ETA: 31s - loss: 1.9344 - accuracy: 0.3012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 history_cnn_7 = model7.fit(train_generator_7, validation_data = validation_generator_7,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
history_cnn_7 = model7.fit(train_generator_7, validation_data = validation_generator_7, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 395/395 [==============================] - 114s 286ms/step - loss: 2.3340 - accuracy: 0.2270 - val_loss: 1.8441 - val_accuracy: 0.4040
# Epoch 2/45
# 395/395 [==============================] - 113s 286ms/step - loss: 1.7770 - accuracy: 0.3787 - val_loss: 1.6367 - val_accuracy: 0.4733
# Epoch 3/45
# 395/395 [==============================] - 112s 283ms/step - loss: 1.5015 - accuracy: 0.4801 - val_loss: 1.4635 - val_accuracy: 0.5088
# Epoch 4/45
# 395/395 [==============================] - 112s 283ms/step - loss: 1.3793 - accuracy: 0.5354 - val_loss: 1.2522 - val_accuracy: 0.5829
# Epoch 5/45
# 395/395 [==============================] - 112s 282ms/step - loss: 1.2253 - accuracy: 0.5925 - val_loss: 1.2208 - val_accuracy: 0.5820
# Epoch 6/45
# 395/395 [==============================] - 111s 282ms/step - loss: 1.1513 - accuracy: 0.6310 - val_loss: 1.2720 - val_accuracy: 0.6171
# Epoch 7/45
# 395/395 [==============================] - 112s 282ms/step - loss: 1.0810 - accuracy: 0.6619 - val_loss: 1.4100 - val_accuracy: 0.6184
# Epoch 8/45
# 395/395 [==============================] - 112s 282ms/step - loss: 1.0161 - accuracy: 0.6935 - val_loss: 1.4086 - val_accuracy: 0.6027
# Epoch 9/45
# 395/395 [==============================] - 112s 283ms/step - loss: 0.9354 - accuracy: 0.7286 - val_loss: 1.2794 - val_accuracy: 0.6342
# Epoch 10/45
# 395/395 [==============================] - 111s 282ms/step - loss: 0.8712 - accuracy: 0.7490 - val_loss: 1.4757 - val_accuracy: 0.5888
# Epoch 11/45
# 395/395 [==============================] - 111s 282ms/step - loss: 0.8173 - accuracy: 0.7749 - val_loss: 1.6455 - val_accuracy: 0.6013
# Epoch 12/45
# 395/395 [==============================] - 111s 281ms/step - loss: 0.7911 - accuracy: 0.7826 - val_loss: 2.0993 - val_accuracy: 0.6265
# Epoch 13/45
# 395/395 [==============================] - 111s 281ms/step - loss: 0.7521 - accuracy: 0.7944 - val_loss: 1.5662 - val_accuracy: 0.6058
# Epoch 14/45
# 395/395 [==============================] - 112s 282ms/step - loss: 0.6906 - accuracy: 0.8188 - val_loss: 1.7270 - val_accuracy: 0.6697
# Epoch 15/45
# 395/395 [==============================] - 112s 283ms/step - loss: 0.6679 - accuracy: 0.8243 - val_loss: 1.5113 - val_accuracy: 0.6342
# Epoch 16/45
# 395/395 [==============================] - 111s 282ms/step - loss: 0.6481 - accuracy: 0.8326 - val_loss: 1.9138 - val_accuracy: 0.6472
# Epoch 17/45
# 395/395 [==============================] - 111s 282ms/step - loss: 0.6438 - accuracy: 0.8410 - val_loss: 1.8696 - val_accuracy: 0.6733
# Epoch 18/45
# 395/395 [==============================] - 116s 293ms/step - loss: 0.5977 - accuracy: 0.8524 - val_loss: 1.6141 - val_accuracy: 0.6890
# Epoch 19/45
# 395/395 [==============================] - 113s 285ms/step - loss: 0.5660 - accuracy: 0.8593 - val_loss: 1.6412 - val_accuracy: 0.6548
# Epoch 20/45
# 395/395 [==============================] - 112s 283ms/step - loss: 0.6012 - accuracy: 0.8524 - val_loss: 1.9081 - val_accuracy: 0.6216
# Epoch 21/45
# 395/395 [==============================] - 112s 282ms/step - loss: 0.6103 - accuracy: 0.8482 - val_loss: 1.8815 - val_accuracy: 0.6611
# Epoch 22/45
# 395/395 [==============================] - 112s 282ms/step - loss: 0.5630 - accuracy: 0.8646 - val_loss: 2.0332 - val_accuracy: 0.6589
# Epoch 23/45
# 395/395 [==============================] - 2623s 7s/step - loss: 0.5718 - accuracy: 0.8669 - val_loss: 1.6269 - val_accuracy: 0.6472

# %% [markdown]
# trying another one 7.31.23

# %%
model7 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model7.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(200, 150, 3), kernel_regularizer = l2(5e-4) ))

# max pool in 2x2 window
model7.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model7.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-3)))
model7.add(MaxPooling2D((2, 2)))

model7.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(7e-3)))
model7.add(Dropout(0.2))

# transition to dense fully-connected part of network
model7.add(Flatten())
model7.add(Dense(128, activation='relu'))
model7.add(Dropout(0.4))

model7.add(BatchNormalization())
model7.add(Dense(64, activation='relu'))
model7.add(Dropout(0.6))

model7.add(Dense(10, activation='softmax'))

model7.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_7 = model7.fit(train_generator_7, validation_data = validation_generator_7, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 395/395 [==============================] - 85s 213ms/step - loss: 2.3539 - accuracy: 0.2072 - val_loss: 2.2096 - val_accuracy: 0.2252
# Epoch 2/45
# 395/395 [==============================] - 85s 214ms/step - loss: 2.0596 - accuracy: 0.2617 - val_loss: 2.4258 - val_accuracy: 0.2710
# Epoch 3/45
# 395/395 [==============================] - 83s 211ms/step - loss: 1.9381 - accuracy: 0.3024 - val_loss: 1.9897 - val_accuracy: 0.3052
# Epoch 4/45
# 395/395 [==============================] - 85s 215ms/step - loss: 1.7947 - accuracy: 0.3551 - val_loss: 1.7621 - val_accuracy: 0.4040
# Epoch 5/45
# 395/395 [==============================] - 84s 211ms/step - loss: 1.7389 - accuracy: 0.3733 - val_loss: 1.7765 - val_accuracy: 0.3762
# Epoch 6/45
# 395/395 [==============================] - 84s 211ms/step - loss: 1.6354 - accuracy: 0.4093 - val_loss: 1.5940 - val_accuracy: 0.4634
# Epoch 7/45
# 395/395 [==============================] - 84s 211ms/step - loss: 1.5174 - accuracy: 0.4614 - val_loss: 1.4417 - val_accuracy: 0.5222
# Epoch 8/45
# 395/395 [==============================] - 86s 217ms/step - loss: 1.4624 - accuracy: 0.4935 - val_loss: 1.4376 - val_accuracy: 0.5007
# Epoch 9/45
# 395/395 [==============================] - 86s 218ms/step - loss: 1.4184 - accuracy: 0.5045 - val_loss: 1.3664 - val_accuracy: 0.4989
# Epoch 10/45
# 395/395 [==============================] - 86s 218ms/step - loss: 1.3218 - accuracy: 0.5498 - val_loss: 1.5364 - val_accuracy: 0.5142
# Epoch 11/45
# 395/395 [==============================] - 2319s 6s/step - loss: 1.2843 - accuracy: 0.5668 - val_loss: 1.3756 - val_accuracy: 0.5604
# Epoch 12/45
# 395/395 [==============================] - 3092s 8s/step - loss: 1.2076 - accuracy: 0.5984 - val_loss: 1.3691 - val_accuracy: 0.5658
# Epoch 13/45
# 395/395 [==============================] - 969s 2s/step - loss: 1.1882 - accuracy: 0.6067 - val_loss: 1.5162 - val_accuracy: 0.5178
# Epoch 14/45
# 395/395 [==============================] - 7208s 18s/step - loss: 1.1827 - accuracy: 0.6108 - val_loss: 1.3330 - val_accuracy: 0.5820
# Epoch 15/45
# 395/395 [==============================] - 1015s 3s/step - loss: 1.0956 - accuracy: 0.6432 - val_loss: 1.2557 - val_accuracy: 0.6135
# Epoch 16/45
# 395/395 [==============================] - 83s 210ms/step - loss: 1.0700 - accuracy: 0.6583 - val_loss: 1.3388 - val_accuracy: 0.5915
# Epoch 17/45
# 395/395 [==============================] - 87s 219ms/step - loss: 1.0887 - accuracy: 0.6518 - val_loss: 1.2170 - val_accuracy: 0.6440
# Epoch 18/45
# 395/395 [==============================] - 83s 210ms/step - loss: 0.9863 - accuracy: 0.6876 - val_loss: 1.2833 - val_accuracy: 0.6369
# Epoch 19/45
# 395/395 [==============================] - 83s 210ms/step - loss: 0.9366 - accuracy: 0.7068 - val_loss: 1.4851 - val_accuracy: 0.5640
# Epoch 20/45
# 395/395 [==============================] - 83s 209ms/step - loss: 0.9029 - accuracy: 0.7155 - val_loss: 2.7387 - val_accuracy: 0.4948
# Epoch 21/45
# 395/395 [==============================] - 81s 206ms/step - loss: 0.8667 - accuracy: 0.7307 - val_loss: 2.3134 - val_accuracy: 0.4661
# Epoch 22/45
# 395/395 [==============================] - 82s 207ms/step - loss: 0.8612 - accuracy: 0.7341 - val_loss: 1.4029 - val_accuracy: 0.6454
# Epoch 23/45
# 395/395 [==============================] - 82s 207ms/step - loss: 0.7950 - accuracy: 0.7588 - val_loss: 1.4054 - val_accuracy: 0.6319
# Epoch 24/45
# 395/395 [==============================] - 82s 207ms/step - loss: 0.7287 - accuracy: 0.7780 - val_loss: 1.5680 - val_accuracy: 0.6494
# Epoch 25/45
# 395/395 [==============================] - 82s 206ms/step - loss: 0.7786 - accuracy: 0.7672 - val_loss: 1.7088 - val_accuracy: 0.5897
# Epoch 26/45
# 395/395 [==============================] - 83s 211ms/step - loss: 0.6805 - accuracy: 0.7992 - val_loss: 1.9311 - val_accuracy: 0.6000
# Epoch 27/45
# 395/395 [==============================] - 86s 216ms/step - loss: 0.6566 - accuracy: 0.8023 - val_loss: 1.9193 - val_accuracy: 0.6319
# Epoch 28/45
# 395/395 [==============================] - 86s 217ms/step - loss: 0.6941 - accuracy: 0.7986 - val_loss: 1.7110 - val_accuracy: 0.6144
# Epoch 29/45
# 395/395 [==============================] - 86s 218ms/step - loss: 0.6710 - accuracy: 0.8048 - val_loss: 1.7324 - val_accuracy: 0.6220

# %%
train_data_gen_7_2 = ImageDataGenerator(rescale = 1./255, validation_split = .15)

train_generator_7_2 = train_data_gen_7_2.flow_from_directory(

                                                    train_dir_2, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'training',)

val_data_gen_7_2 = ImageDataGenerator(rescale=1./255)

validation_generator_7_2 = train_data_gen_7_2.flow_from_directory(
    
                                                    train_dir_2, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'validation',)

test_data_gen_7_2 = ImageDataGenerator(rescale=1./255)

test_generator_7_2 = test_data_gen_7_2.flow_from_directory(

                                                    test_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    shuffle = False)

# %%
model15 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model15.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(200, 150, 3)))

model15.add(BatchNormalization())
model15.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.

model15.add(Conv2D(64, (3, 3), activation='relu'))
model15.add(BatchNormalization())
model15.add(MaxPooling2D((2, 2)))

model15.add(Conv2D(64, (3, 3), activation='relu'))
model15.add(BatchNormalization())
model15.add(MaxPooling2D((2, 2)))

# transition to dense fully-connected part of network
model15.add(GlobalAveragePooling2D())

model15.add(Dense(10, activation='softmax'))

model15.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_7_2 = model7_2.fit(train_generator_7_2, validation_data = validation_generator_7_2, 
                           epochs = 45, callbacks=[custom_early_stopping])
