# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense # creates densely connected layer object
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array

from tensorflow import keras
from tensorflow.keras import datasets, layers, models

from tensorflow.keras.layers import Conv2D # convolution layer
from tensorflow.keras.layers import MaxPooling2D # max pooling layer

from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

from keras.preprocessing.image import ImageDataGenerator

# %%
custom_early_stopping = EarlyStopping(monitor='val_accuracy', patience=5) 
callbacks=[custom_early_stopping]

# %%
train_dir = 'Data/train_log_spect'

test_dir = 'Data/test_log_spect'

# %%
train_data_gen_7 = ImageDataGenerator(rescale = 1./255, validation_split = .15)

train_generator_7 = train_data_gen_7.flow_from_directory(

                                                    train_dir, 
                                                    target_size = (200, 150),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'training',)

val_data_gen_7 = ImageDataGenerator(rescale=1./255)

validation_generator_7 = train_data_gen_7.flow_from_directory(
    
                                                    train_dir, 
                                                    target_size = (200, 150),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'validation',)

test_data_gen_7 = ImageDataGenerator(rescale=1./255)

test_generator_7 = test_data_gen_7.flow_from_directory(

                                                    test_dir, 
                                                    target_size = (200, 150),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    shuffle = False)
# Out:
# Found 6314 images belonging to 10 classes.
# Found 1108 images belonging to 10 classes.
# Found 1310 images belonging to 10 classes.

# %%
model7 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model7.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(200, 150, 3), kernel_regularizer = l2(5e-4) ))

# max pool in 2x2 window
model7.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model7.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-3)))
model7.add(MaxPooling2D((2, 2)))

model7.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(7e-3)))
model7.add(Dropout(0.25))

# transition to dense fully-connected part of network
model7.add(Flatten())
model7.add(Dense(128, activation='relu'))
model7.add(Dropout(0.5))

model7.add(BatchNormalization())
model7.add(Dense(64, activation='relu'))
model7.add(Dropout(0.7))

model7.add(Dense(10, activation='softmax'))

model7.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_7 = model7.fit(train_generator_7, validation_data = validation_generator_7, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 63s 314ms/step - loss: 2.7704 - accuracy: 0.1544 - val_loss: 2.3110 - val_accuracy: 0.2780
# Epoch 2/45
# 198/198 [==============================] - 61s 308ms/step - loss: 2.3176 - accuracy: 0.1948 - val_loss: 2.2144 - val_accuracy: 0.1913
# Epoch 3/45
# 198/198 [==============================] - 61s 306ms/step - loss: 2.2341 - accuracy: 0.2081 - val_loss: 2.4508 - val_accuracy: 0.2545
# Epoch 4/45
# 198/198 [==============================] - 60s 303ms/step - loss: 2.1544 - accuracy: 0.2380 - val_loss: 1.9884 - val_accuracy: 0.2852
# Epoch 5/45
# 174/198 [=========================>....] - ETA: 6s - loss: 2.0947 - accuracy: 0.2546

# %%
train_data_gen_1 = ImageDataGenerator(rescale = 1./255, validation_split = .15)

train_generator_1 = train_data_gen_1.flow_from_directory(

                                                    train_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'training',)

val_data_gen_1 = ImageDataGenerator(rescale=1./255)

validation_generator_1 = train_data_gen_1.flow_from_directory(
    
                                                    train_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'validation',)

test_data_gen_1 = ImageDataGenerator(rescale=1./255)

test_generator_1 = test_data_gen_1.flow_from_directory(

                                                    test_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    shuffle = False)
# Out:
# Found 6314 images belonging to 10 classes.
# Found 1108 images belonging to 10 classes.
# Found 1310 images belonging to 10 classes.

# %%
model1 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model1.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))

# max pool in 2x2 window
model1.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model1.add(Conv2D(64, (3, 3), activation='relu'))
model1.add(MaxPooling2D((2, 2)))

model1.add(Conv2D(64, (3, 3), activation='relu'))
model1.add(Dropout(0.1))

# transition to dense fully-connected part of network
model1.add(Flatten())
model1.add(Dense(128, activation='relu'))
model1.add(Dropout(0.2))

model1.add(BatchNormalization())
model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.5))

model1.add(Dense(10, activation='softmax'))

model1.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_1 = model1.fit(train_generator_1, validation_data = validation_generator_1, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 41s 205ms/step - loss: 2.0646 - accuracy: 0.2616 - val_loss: 1.8278 - val_accuracy: 0.3204
# Epoch 2/45
# 198/198 [==============================] - 40s 200ms/step - loss: 1.7669 - accuracy: 0.3554 - val_loss: 2.0802 - val_accuracy: 0.2130
# Epoch 3/45
# 198/198 [==============================] - 40s 202ms/step - loss: 1.4835 - accuracy: 0.4756 - val_loss: 1.7633 - val_accuracy: 0.3646
# Epoch 4/45
# 198/198 [==============================] - 40s 202ms/step - loss: 1.2426 - accuracy: 0.5816 - val_loss: 1.3504 - val_accuracy: 0.5641
# Epoch 5/45
# 198/198 [==============================] - 40s 200ms/step - loss: 1.0532 - accuracy: 0.6470 - val_loss: 1.1735 - val_accuracy: 0.5975
# Epoch 6/45
# 198/198 [==============================] - 41s 207ms/step - loss: 0.8878 - accuracy: 0.7087 - val_loss: 1.3155 - val_accuracy: 0.5948
# Epoch 7/45
# 198/198 [==============================] - 40s 201ms/step - loss: 0.7479 - accuracy: 0.7629 - val_loss: 1.4294 - val_accuracy: 0.5767
# Epoch 8/45
# 198/198 [==============================] - 40s 202ms/step - loss: 0.6436 - accuracy: 0.7979 - val_loss: 1.4975 - val_accuracy: 0.5821
# Epoch 9/45
# 198/198 [==============================] - 40s 203ms/step - loss: 0.5794 - accuracy: 0.8212 - val_loss: 1.2995 - val_accuracy: 0.6255
# Epoch 10/45
# 198/198 [==============================] - 40s 203ms/step - loss: 0.4840 - accuracy: 0.8492 - val_loss: 1.4363 - val_accuracy: 0.6426
# Epoch 11/45
#  46/198 [=====>........................] - ETA: 26s - loss: 0.3629 - accuracy: 0.8933
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 history_cnn_1 = model1.fit(train_generator_1, validation_data = validation_generator_1,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model2 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model2.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))
model2.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.1))

model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.25))

# transition to dense fully-connected part of network
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.25))

model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_2 = model2.fit(train_generator_1, validation_data = validation_generator_1, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 42s 211ms/step - loss: 2.0910 - accuracy: 0.2610 - val_loss: 1.9073 - val_accuracy: 0.2671
# Epoch 2/45
# 198/198 [==============================] - 39s 197ms/step - loss: 1.6638 - accuracy: 0.4113 - val_loss: 1.8036 - val_accuracy: 0.3745
# Epoch 3/45
# 198/198 [==============================] - 40s 199ms/step - loss: 1.3654 - accuracy: 0.5310 - val_loss: 1.5096 - val_accuracy: 0.4955
# Epoch 4/45
# 198/198 [==============================] - 39s 196ms/step - loss: 1.1823 - accuracy: 0.6034 - val_loss: 1.3608 - val_accuracy: 0.5587
# Epoch 5/45
# 198/198 [==============================] - 40s 203ms/step - loss: 1.0433 - accuracy: 0.6525 - val_loss: 1.5717 - val_accuracy: 0.5442
# Epoch 6/45
# 198/198 [==============================] - 44s 222ms/step - loss: 0.9029 - accuracy: 0.7086 - val_loss: 1.2917 - val_accuracy: 0.6200
# Epoch 7/45
# 198/198 [==============================] - 42s 212ms/step - loss: 0.7738 - accuracy: 0.7553 - val_loss: 1.2553 - val_accuracy: 0.6101
# Epoch 8/45
# 198/198 [==============================] - 45s 229ms/step - loss: 0.7448 - accuracy: 0.7615 - val_loss: 1.3124 - val_accuracy: 0.6092
# Epoch 9/45
# 198/198 [==============================] - 40s 201ms/step - loss: 0.6505 - accuracy: 0.7957 - val_loss: 1.4242 - val_accuracy: 0.6209
# Epoch 10/45
# 198/198 [==============================] - 40s 204ms/step - loss: 0.5854 - accuracy: 0.8134 - val_loss: 1.3814 - val_accuracy: 0.6209
# Epoch 11/45
#  33/198 [====>.........................] - ETA: 28s - loss: 0.4602 - accuracy: 0.8570
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 history_cnn_2 = model2.fit(train_generator_1, validation_data = validation_generator_1,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model2 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model2.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))
model2.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.25))

model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.25))

# transition to dense fully-connected part of network
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.35))

model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_2 = model2.fit(train_generator_1, validation_data = validation_generator_1, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 42s 209ms/step - loss: 2.1436 - accuracy: 0.2395 - val_loss: 1.9572 - val_accuracy: 0.2527
# Epoch 2/45
# 198/198 [==============================] - 41s 204ms/step - loss: 1.8366 - accuracy: 0.3364 - val_loss: 1.8583 - val_accuracy: 0.2951
# Epoch 3/45
# 198/198 [==============================] - 42s 210ms/step - loss: 1.6256 - accuracy: 0.4254 - val_loss: 1.7315 - val_accuracy: 0.3682
# Epoch 4/45
# 198/198 [==============================] - 42s 214ms/step - loss: 1.4122 - accuracy: 0.5146 - val_loss: 1.6662 - val_accuracy: 0.4440
# Epoch 5/45
# 198/198 [==============================] - 45s 229ms/step - loss: 1.2577 - accuracy: 0.5809 - val_loss: 1.3960 - val_accuracy: 0.5199
# Epoch 6/45
# 198/198 [==============================] - 46s 232ms/step - loss: 1.1662 - accuracy: 0.6072 - val_loss: 1.2851 - val_accuracy: 0.5208
# Epoch 7/45
# 198/198 [==============================] - 42s 214ms/step - loss: 1.0441 - accuracy: 0.6573 - val_loss: 1.2398 - val_accuracy: 0.5460
# Epoch 8/45
# 198/198 [==============================] - 42s 209ms/step - loss: 0.9865 - accuracy: 0.6826 - val_loss: 1.2255 - val_accuracy: 0.6020
# Epoch 9/45
# 198/198 [==============================] - 41s 205ms/step - loss: 0.8612 - accuracy: 0.7227 - val_loss: 1.2646 - val_accuracy: 0.5894
# Epoch 10/45
# 198/198 [==============================] - 40s 204ms/step - loss: 0.8199 - accuracy: 0.7369 - val_loss: 1.2592 - val_accuracy: 0.5894
# Epoch 11/45
# 198/198 [==============================] - 40s 202ms/step - loss: 0.8077 - accuracy: 0.7452 - val_loss: 1.4009 - val_accuracy: 0.5451
# Epoch 12/45
# 198/198 [==============================] - 40s 203ms/step - loss: 0.6807 - accuracy: 0.7819 - val_loss: 1.5013 - val_accuracy: 0.5758
# Epoch 13/45
# 198/198 [==============================] - 40s 203ms/step - loss: 0.6619 - accuracy: 0.7970 - val_loss: 1.4224 - val_accuracy: 0.5894

# %%
train_dir = 'Data/mel_train_85_15'

test_dir = 'Data/mel_test_85_15'

# %%
train_data_gen_3 = ImageDataGenerator(rescale = 1./255, validation_split = .15)

train_generator_3 = train_data_gen_3.flow_from_directory(

                                                    train_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'training',)

val_data_gen_3 = ImageDataGenerator(rescale=1./255)

validation_generator_3 = train_data_gen_3.flow_from_directory(
    
                                                    train_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    subset = 'validation',)

test_data_gen_3 = ImageDataGenerator(rescale=1./255)

test_generator_3 = test_data_gen_3.flow_from_directory(

                                                    test_dir, 
                                                    target_size = (160, 120),
                                                    batch_size = 32,
                                                    class_mode = 'categorical',
                                                    color_mode = 'rgb',
                                                    seed = 42,
                                                    shuffle = False)
# Out:
# Found 6314 images belonging to 10 classes.
# Found 1108 images belonging to 10 classes.
# Found 1310 images belonging to 10 classes.

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.35))

model3.add(BatchNormalization())
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3 = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 42s 210ms/step - loss: 2.1485 - accuracy: 0.2333 - val_loss: 2.0170 - val_accuracy: 0.2671
# Epoch 2/45
# 198/198 [==============================] - 43s 214ms/step - loss: 1.6859 - accuracy: 0.3947 - val_loss: 1.5992 - val_accuracy: 0.3917
# Epoch 3/45
# 198/198 [==============================] - 39s 196ms/step - loss: 1.4222 - accuracy: 0.5101 - val_loss: 1.5568 - val_accuracy: 0.4693
# Epoch 4/45
# 198/198 [==============================] - 39s 195ms/step - loss: 1.2312 - accuracy: 0.5744 - val_loss: 1.6398 - val_accuracy: 0.4684
# Epoch 5/45
# 198/198 [==============================] - 39s 194ms/step - loss: 1.0921 - accuracy: 0.6278 - val_loss: 1.2782 - val_accuracy: 0.5406
# Epoch 6/45
# 198/198 [==============================] - 38s 192ms/step - loss: 0.9977 - accuracy: 0.6734 - val_loss: 1.2488 - val_accuracy: 0.5542
# Epoch 7/45
# 198/198 [==============================] - 40s 202ms/step - loss: 0.9008 - accuracy: 0.7029 - val_loss: 1.4685 - val_accuracy: 0.5650
# Epoch 8/45
# 198/198 [==============================] - 39s 195ms/step - loss: 0.8062 - accuracy: 0.7390 - val_loss: 1.4430 - val_accuracy: 0.5704
# Epoch 9/45
#  17/198 [=>............................] - ETA: 30s - loss: 0.6320 - accuracy: 0.7923
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 history_cnn_3 = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.2))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.25))

model3.add(BatchNormalization())
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3 = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 40s 199ms/step - loss: 2.2358 - accuracy: 0.2235 - val_loss: 1.9795 - val_accuracy: 0.3096
# Epoch 2/45
# 198/198 [==============================] - 40s 201ms/step - loss: 1.7536 - accuracy: 0.3621 - val_loss: 1.7810 - val_accuracy: 0.3267
# Epoch 3/45
# 198/198 [==============================] - 38s 191ms/step - loss: 1.5180 - accuracy: 0.4498 - val_loss: 1.4919 - val_accuracy: 0.4495
# Epoch 4/45
# 198/198 [==============================] - 38s 190ms/step - loss: 1.3115 - accuracy: 0.5429 - val_loss: 1.5315 - val_accuracy: 0.4928
# Epoch 5/45
# 198/198 [==============================] - 38s 192ms/step - loss: 1.1536 - accuracy: 0.6079 - val_loss: 1.3236 - val_accuracy: 0.5794
# Epoch 6/45
# 198/198 [==============================] - 38s 191ms/step - loss: 1.0566 - accuracy: 0.6460 - val_loss: 1.2693 - val_accuracy: 0.5930
# Epoch 7/45
# 198/198 [==============================] - 38s 191ms/step - loss: 0.9343 - accuracy: 0.6831 - val_loss: 1.3424 - val_accuracy: 0.5126
# Epoch 8/45
# 198/198 [==============================] - 38s 190ms/step - loss: 0.8298 - accuracy: 0.7201 - val_loss: 1.2774 - val_accuracy: 0.5668
# Epoch 9/45
# 198/198 [==============================] - 38s 189ms/step - loss: 0.7795 - accuracy: 0.7390 - val_loss: 1.2546 - val_accuracy: 0.6020
# Epoch 10/45
# 198/198 [==============================] - 37s 187ms/step - loss: 0.6726 - accuracy: 0.7843 - val_loss: 1.2403 - val_accuracy: 0.6291
# Epoch 11/45
# 198/198 [==============================] - 38s 192ms/step - loss: 0.6225 - accuracy: 0.7941 - val_loss: 1.4008 - val_accuracy: 0.6164
# Epoch 12/45
# 198/198 [==============================] - 37s 188ms/step - loss: 0.6031 - accuracy: 0.8085 - val_loss: 1.3695 - val_accuracy: 0.6056
# Epoch 13/45
#  14/198 [=>............................] - ETA: 30s - loss: 0.5226 - accuracy: 0.8259
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 history_cnn_3 = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3), kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.3))

model3.add(BatchNormalization())
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3 = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 39s 193ms/step - loss: 2.3013 - accuracy: 0.2197 - val_loss: 2.0218 - val_accuracy: 0.3312
# Epoch 2/45
# 198/198 [==============================] - 38s 192ms/step - loss: 1.8765 - accuracy: 0.3326 - val_loss: 1.9162 - val_accuracy: 0.3709
# Epoch 3/45
# 198/198 [==============================] - 38s 191ms/step - loss: 1.6496 - accuracy: 0.4346 - val_loss: 1.5433 - val_accuracy: 0.4819
# Epoch 4/45
# 198/198 [==============================] - 38s 194ms/step - loss: 1.4435 - accuracy: 0.5149 - val_loss: 1.4513 - val_accuracy: 0.5171
# Epoch 5/45
# 198/198 [==============================] - 40s 202ms/step - loss: 1.2995 - accuracy: 0.5613 - val_loss: 1.5977 - val_accuracy: 0.4801
# Epoch 6/45
# 198/198 [==============================] - 41s 206ms/step - loss: 1.2001 - accuracy: 0.6012 - val_loss: 1.2472 - val_accuracy: 0.6056
# Epoch 7/45
# 198/198 [==============================] - 38s 193ms/step - loss: 1.0623 - accuracy: 0.6641 - val_loss: 1.3559 - val_accuracy: 0.6065
# Epoch 8/45
# 198/198 [==============================] - 39s 194ms/step - loss: 1.0073 - accuracy: 0.6856 - val_loss: 1.2951 - val_accuracy: 0.6119
# Epoch 9/45
# 198/198 [==============================] - 38s 191ms/step - loss: 0.9146 - accuracy: 0.7135 - val_loss: 1.1851 - val_accuracy: 0.6516
# Epoch 10/45
# 198/198 [==============================] - 38s 190ms/step - loss: 0.9164 - accuracy: 0.7258 - val_loss: 1.2409 - val_accuracy: 0.6588
# Epoch 11/45
# 198/198 [==============================] - 37s 189ms/step - loss: 0.8103 - accuracy: 0.7542 - val_loss: 1.3484 - val_accuracy: 0.5668
# Epoch 12/45
# 198/198 [==============================] - 38s 191ms/step - loss: 0.7472 - accuracy: 0.7889 - val_loss: 1.3979 - val_accuracy: 0.6074
# Epoch 13/45
# 198/198 [==============================] - 38s 191ms/step - loss: 0.7412 - accuracy: 0.7735 - val_loss: 1.3376 - val_accuracy: 0.6489
# Epoch 14/45
# 198/198 [==============================] - 37s 189ms/step - loss: 0.6927 - accuracy: 0.8016 - val_loss: 1.5259 - val_accuracy: 0.5884
# Epoch 15/45
# 198/198 [==============================] - 38s 191ms/step - loss: 0.6971 - accuracy: 0.8084 - val_loss: 1.3353 - val_accuracy: 0.6200

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3), kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-3) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_b = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 34s 171ms/step - loss: 2.3588 - accuracy: 0.1918 - val_loss: 2.1364 - val_accuracy: 0.2437
# Epoch 2/45
# 198/198 [==============================] - 34s 169ms/step - loss: 2.0834 - accuracy: 0.2558 - val_loss: 2.0026 - val_accuracy: 0.2690
# Epoch 3/45
# 198/198 [==============================] - 34s 170ms/step - loss: 1.9786 - accuracy: 0.2833 - val_loss: 1.9710 - val_accuracy: 0.2744
# Epoch 4/45
# 198/198 [==============================] - 34s 174ms/step - loss: 1.9024 - accuracy: 0.3118 - val_loss: 2.1376 - val_accuracy: 0.2238
# Epoch 5/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.8247 - accuracy: 0.3372 - val_loss: 1.8203 - val_accuracy: 0.3249
# Epoch 6/45
# 198/198 [==============================] - 33s 165ms/step - loss: 1.7244 - accuracy: 0.3871 - val_loss: 1.6607 - val_accuracy: 0.4269
# Epoch 7/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.5952 - accuracy: 0.4397 - val_loss: 1.5860 - val_accuracy: 0.4738
# Epoch 8/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.5442 - accuracy: 0.4579 - val_loss: 1.5767 - val_accuracy: 0.4973
# Epoch 9/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.4873 - accuracy: 0.4826 - val_loss: 1.5735 - val_accuracy: 0.4648
# Epoch 10/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.4043 - accuracy: 0.5052 - val_loss: 1.5694 - val_accuracy: 0.4756
# Epoch 11/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.3989 - accuracy: 0.5320 - val_loss: 1.4405 - val_accuracy: 0.5099
# Epoch 12/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.3629 - accuracy: 0.5453 - val_loss: 1.4479 - val_accuracy: 0.5063
# Epoch 13/45
# 198/198 [==============================] - 34s 169ms/step - loss: 1.3006 - accuracy: 0.5613 - val_loss: 1.3766 - val_accuracy: 0.4883
# Epoch 14/45
# 198/198 [==============================] - 35s 176ms/step - loss: 1.2640 - accuracy: 0.5811 - val_loss: 1.5553 - val_accuracy: 0.4892
# Epoch 15/45
# 198/198 [==============================] - 34s 173ms/step - loss: 1.2389 - accuracy: 0.5898 - val_loss: 1.4986 - val_accuracy: 0.4892
# Epoch 16/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.2254 - accuracy: 0.5988 - val_loss: 1.3343 - val_accuracy: 0.5397
# Epoch 17/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.1893 - accuracy: 0.6075 - val_loss: 1.3873 - val_accuracy: 0.5370
# Epoch 18/45
# 198/198 [==============================] - 36s 181ms/step - loss: 1.1508 - accuracy: 0.6281 - val_loss: 1.3691 - val_accuracy: 0.5442
# Epoch 19/45
# 198/198 [==============================] - 37s 184ms/step - loss: 1.1466 - accuracy: 0.6240 - val_loss: 1.4448 - val_accuracy: 0.4991
# Epoch 20/45
# 198/198 [==============================] - 37s 187ms/step - loss: 1.1376 - accuracy: 0.6367 - val_loss: 1.4493 - val_accuracy: 0.5325
# Epoch 21/45
#  46/198 [=====>........................] - ETA: 22s - loss: 1.1407 - accuracy: 0.6338
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 history_cnn_3_b = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3), kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-3) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_c = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 35s 174ms/step - loss: 2.4815 - accuracy: 0.2176 - val_loss: 2.2935 - val_accuracy: 0.2329
# Epoch 2/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.9626 - accuracy: 0.3404 - val_loss: 1.9725 - val_accuracy: 0.3240
# Epoch 3/45
# 198/198 [==============================] - 36s 181ms/step - loss: 1.6592 - accuracy: 0.4523 - val_loss: 1.5575 - val_accuracy: 0.4774
# Epoch 4/45
# 198/198 [==============================] - 34s 172ms/step - loss: 1.4895 - accuracy: 0.5101 - val_loss: 1.4914 - val_accuracy: 0.4666
# Epoch 5/45
# 198/198 [==============================] - 37s 188ms/step - loss: 1.3377 - accuracy: 0.5584 - val_loss: 1.5648 - val_accuracy: 0.4838
# Epoch 6/45
# 198/198 [==============================] - 36s 182ms/step - loss: 1.2430 - accuracy: 0.6012 - val_loss: 1.4741 - val_accuracy: 0.5361
# Epoch 7/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.1351 - accuracy: 0.6487 - val_loss: 1.5818 - val_accuracy: 0.5560
# Epoch 8/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.0867 - accuracy: 0.6644 - val_loss: 1.2624 - val_accuracy: 0.6345
# Epoch 9/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.0176 - accuracy: 0.6866 - val_loss: 1.3497 - val_accuracy: 0.5686
# Epoch 10/45
# 198/198 [==============================] - 34s 172ms/step - loss: 0.9346 - accuracy: 0.7244 - val_loss: 1.3881 - val_accuracy: 0.6011
# Epoch 11/45
# 198/198 [==============================] - 35s 176ms/step - loss: 0.8537 - accuracy: 0.7455 - val_loss: 1.4566 - val_accuracy: 0.5758
# Epoch 12/45
# 198/198 [==============================] - 34s 171ms/step - loss: 0.8398 - accuracy: 0.7570 - val_loss: 1.4803 - val_accuracy: 0.6435
# Epoch 13/45
# 198/198 [==============================] - 34s 170ms/step - loss: 0.8053 - accuracy: 0.7654 - val_loss: 1.2390 - val_accuracy: 0.6579
# Epoch 14/45
# 198/198 [==============================] - 35s 174ms/step - loss: 0.7555 - accuracy: 0.7797 - val_loss: 1.3673 - val_accuracy: 0.6309
# Epoch 15/45
# 198/198 [==============================] - 35s 174ms/step - loss: 0.7379 - accuracy: 0.7890 - val_loss: 1.3292 - val_accuracy: 0.6101
# Epoch 16/45
# 198/198 [==============================] - 34s 173ms/step - loss: 0.6947 - accuracy: 0.8065 - val_loss: 1.5819 - val_accuracy: 0.6056
# Epoch 17/45
# 198/198 [==============================] - 34s 170ms/step - loss: 0.6573 - accuracy: 0.8112 - val_loss: 1.3674 - val_accuracy: 0.6543
# Epoch 18/45
# 198/198 [==============================] - 33s 168ms/step - loss: 0.6466 - accuracy: 0.8228 - val_loss: 1.5016 - val_accuracy: 0.6318

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3), kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

model3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-3) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_d = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 43s 217ms/step - loss: 2.6468 - accuracy: 0.1802 - val_loss: 2.2169 - val_accuracy: 0.2626
# Epoch 2/45
# 198/198 [==============================] - 40s 201ms/step - loss: 2.1454 - accuracy: 0.2582 - val_loss: 2.1092 - val_accuracy: 0.2518
# Epoch 3/45
# 198/198 [==============================] - 39s 196ms/step - loss: 1.9721 - accuracy: 0.3068 - val_loss: 1.9983 - val_accuracy: 0.2726
# Epoch 4/45
# 198/198 [==============================] - 48s 245ms/step - loss: 1.8014 - accuracy: 0.3692 - val_loss: 1.9086 - val_accuracy: 0.3177
# Epoch 5/45
# 198/198 [==============================] - 42s 209ms/step - loss: 1.6403 - accuracy: 0.4303 - val_loss: 1.8810 - val_accuracy: 0.3971
# Epoch 6/45
# 198/198 [==============================] - 40s 203ms/step - loss: 1.5436 - accuracy: 0.4705 - val_loss: 1.6491 - val_accuracy: 0.3971
# Epoch 7/45
# 198/198 [==============================] - 39s 197ms/step - loss: 1.4511 - accuracy: 0.5049 - val_loss: 1.5639 - val_accuracy: 0.4747
# Epoch 8/45
# 198/198 [==============================] - 38s 191ms/step - loss: 1.3764 - accuracy: 0.5459 - val_loss: 1.6006 - val_accuracy: 0.4395
# Epoch 9/45
# 198/198 [==============================] - 39s 195ms/step - loss: 1.2693 - accuracy: 0.5809 - val_loss: 1.8801 - val_accuracy: 0.4043
# Epoch 10/45
# 198/198 [==============================] - 42s 213ms/step - loss: 1.1856 - accuracy: 0.6121 - val_loss: 1.4362 - val_accuracy: 0.4576
# Epoch 11/45
# 198/198 [==============================] - 43s 219ms/step - loss: 1.1282 - accuracy: 0.6253 - val_loss: 1.3673 - val_accuracy: 0.5551
# Epoch 12/45
# 198/198 [==============================] - 39s 197ms/step - loss: 1.0934 - accuracy: 0.6482 - val_loss: 1.4093 - val_accuracy: 0.5072
# Epoch 13/45
# 198/198 [==============================] - 39s 198ms/step - loss: 1.0250 - accuracy: 0.6756 - val_loss: 1.5329 - val_accuracy: 0.4829
# Epoch 14/45
#  24/198 [==>...........................] - ETA: 30s - loss: 0.9876 - accuracy: 0.7018
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 history_cnn_3_d = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(160, 120, 3), kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-3) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_e = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 33s 162ms/step - loss: 2.4824 - accuracy: 0.2021 - val_loss: 2.2321 - val_accuracy: 0.2410
# Epoch 2/45
# 198/198 [==============================] - 32s 164ms/step - loss: 1.9668 - accuracy: 0.3237 - val_loss: 1.9241 - val_accuracy: 0.4070
# Epoch 3/45
# 198/198 [==============================] - 32s 160ms/step - loss: 1.7192 - accuracy: 0.4170 - val_loss: 1.6611 - val_accuracy: 0.4134
# Epoch 4/45
# 198/198 [==============================] - 34s 171ms/step - loss: 1.5629 - accuracy: 0.4663 - val_loss: 1.6829 - val_accuracy: 0.4242
# Epoch 5/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.4018 - accuracy: 0.5258 - val_loss: 1.5432 - val_accuracy: 0.4666
# Epoch 6/45
# 198/198 [==============================] - 32s 164ms/step - loss: 1.3166 - accuracy: 0.5679 - val_loss: 1.5207 - val_accuracy: 0.5090
# Epoch 7/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.2240 - accuracy: 0.6020 - val_loss: 1.5342 - val_accuracy: 0.4684
# Epoch 8/45
# 198/198 [==============================] - 34s 174ms/step - loss: 1.1442 - accuracy: 0.6307 - val_loss: 1.4025 - val_accuracy: 0.5054
# Epoch 9/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.0757 - accuracy: 0.6568 - val_loss: 1.5106 - val_accuracy: 0.5496
# Epoch 10/45
# 198/198 [==============================] - 33s 165ms/step - loss: 1.0150 - accuracy: 0.6804 - val_loss: 1.5245 - val_accuracy: 0.5289
# Epoch 11/45
# 198/198 [==============================] - 33s 166ms/step - loss: 0.9512 - accuracy: 0.7019 - val_loss: 1.5341 - val_accuracy: 0.5930
# Epoch 12/45
# 198/198 [==============================] - 32s 163ms/step - loss: 0.9214 - accuracy: 0.7168 - val_loss: 1.4826 - val_accuracy: 0.5569
# Epoch 13/45
# 198/198 [==============================] - 33s 167ms/step - loss: 0.8630 - accuracy: 0.7398 - val_loss: 1.3397 - val_accuracy: 0.6182
# Epoch 14/45
# 198/198 [==============================] - 32s 162ms/step - loss: 0.8472 - accuracy: 0.7447 - val_loss: 1.8084 - val_accuracy: 0.5722
# Epoch 15/45
# 198/198 [==============================] - 34s 173ms/step - loss: 0.7908 - accuracy: 0.7620 - val_loss: 1.4775 - val_accuracy: 0.6065
# Epoch 16/45
# 198/198 [==============================] - 33s 168ms/step - loss: 0.7533 - accuracy: 0.7724 - val_loss: 1.5115 - val_accuracy: 0.5650
# Epoch 17/45
# 198/198 [==============================] - 33s 166ms/step - loss: 0.7322 - accuracy: 0.7824 - val_loss: 1.3493 - val_accuracy: 0.6245
# Epoch 18/45
# 198/198 [==============================] - 33s 166ms/step - loss: 0.6926 - accuracy: 0.7974 - val_loss: 1.3890 - val_accuracy: 0.6435
# Epoch 19/45
# 198/198 [==============================] - 32s 162ms/step - loss: 0.6504 - accuracy: 0.8095 - val_loss: 1.7041 - val_accuracy: 0.6056
# Epoch 20/45
# 198/198 [==============================] - 32s 163ms/step - loss: 0.6538 - accuracy: 0.8126 - val_loss: 1.5616 - val_accuracy: 0.5875
# Epoch 21/45
# 198/198 [==============================] - 33s 164ms/step - loss: 0.6600 - accuracy: 0.8050 - val_loss: 1.3271 - val_accuracy: 0.6110
# Epoch 22/45
#  96/198 [=============>................] - ETA: 14s - loss: 0.6343 - accuracy: 0.8174

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(160, 120, 3), kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-3) ))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_f = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 33s 163ms/step - loss: 2.5339 - accuracy: 0.1807 - val_loss: 2.4141 - val_accuracy: 0.1480
# Epoch 2/45
# 198/198 [==============================] - 33s 164ms/step - loss: 2.0330 - accuracy: 0.2892 - val_loss: 1.9545 - val_accuracy: 0.3032
# Epoch 3/45
# 198/198 [==============================] - 32s 163ms/step - loss: 1.8118 - accuracy: 0.3647 - val_loss: 1.7900 - val_accuracy: 0.4314
# Epoch 4/45
# 198/198 [==============================] - 32s 162ms/step - loss: 1.7145 - accuracy: 0.3988 - val_loss: 2.2160 - val_accuracy: 0.3204
# Epoch 5/45
# 198/198 [==============================] - 34s 169ms/step - loss: 1.5928 - accuracy: 0.4482 - val_loss: 1.6673 - val_accuracy: 0.4251
# Epoch 6/45
# 198/198 [==============================] - 35s 175ms/step - loss: 1.4959 - accuracy: 0.4843 - val_loss: 1.5611 - val_accuracy: 0.4801
# Epoch 7/45
# 198/198 [==============================] - 34s 171ms/step - loss: 1.3881 - accuracy: 0.5339 - val_loss: 1.6805 - val_accuracy: 0.4549
# Epoch 8/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.2977 - accuracy: 0.5683 - val_loss: 2.0642 - val_accuracy: 0.4170
# Epoch 9/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.2741 - accuracy: 0.5776 - val_loss: 1.4834 - val_accuracy: 0.5126
# Epoch 10/45
# 198/198 [==============================] - 33s 165ms/step - loss: 1.1288 - accuracy: 0.6334 - val_loss: 1.5428 - val_accuracy: 0.5352
# Epoch 11/45
# 198/198 [==============================] - 32s 164ms/step - loss: 1.0883 - accuracy: 0.6513 - val_loss: 1.7053 - val_accuracy: 0.5253
# Epoch 12/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.0275 - accuracy: 0.6718 - val_loss: 1.4293 - val_accuracy: 0.5614
# Epoch 13/45
# 198/198 [==============================] - 33s 167ms/step - loss: 0.9388 - accuracy: 0.7102 - val_loss: 1.6395 - val_accuracy: 0.5650
# Epoch 14/45
# 198/198 [==============================] - 33s 164ms/step - loss: 0.9058 - accuracy: 0.7151 - val_loss: 1.4473 - val_accuracy: 0.5487
# Epoch 15/45
# 198/198 [==============================] - 32s 163ms/step - loss: 0.8579 - accuracy: 0.7417 - val_loss: 1.3319 - val_accuracy: 0.5875
# Epoch 16/45
# 198/198 [==============================] - 33s 164ms/step - loss: 0.8132 - accuracy: 0.7463 - val_loss: 1.3775 - val_accuracy: 0.6146
# Epoch 17/45
# 198/198 [==============================] - 33s 166ms/step - loss: 0.7775 - accuracy: 0.7689 - val_loss: 1.5248 - val_accuracy: 0.6029
# Epoch 18/45
# 198/198 [==============================] - 34s 170ms/step - loss: 0.7381 - accuracy: 0.7811 - val_loss: 1.4060 - val_accuracy: 0.6164
# Epoch 19/45
# 198/198 [==============================] - 33s 167ms/step - loss: 0.6926 - accuracy: 0.7924 - val_loss: 1.4561 - val_accuracy: 0.5632
# Epoch 20/45
# 198/198 [==============================] - 33s 166ms/step - loss: 0.6895 - accuracy: 0.8033 - val_loss: 1.9840 - val_accuracy: 0.5343
# Epoch 21/45
#  14/198 [=>............................] - ETA: 26s - loss: 0.7377 - accuracy: 0.7857
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 history_cnn_3_f = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(160, 120, 3), 
                  kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(Dropout(0.25))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_g = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 37s 182ms/step - loss: 2.1170 - accuracy: 0.2677 - val_loss: 2.0363 - val_accuracy: 0.2906
# Epoch 2/45
# 198/198 [==============================] - 36s 182ms/step - loss: 1.7292 - accuracy: 0.3969 - val_loss: 2.2484 - val_accuracy: 0.2870
# Epoch 3/45
# 198/198 [==============================] - 34s 169ms/step - loss: 1.4628 - accuracy: 0.4997 - val_loss: 1.8051 - val_accuracy: 0.4088
# Epoch 4/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.3252 - accuracy: 0.5548 - val_loss: 1.5164 - val_accuracy: 0.4991
# Epoch 5/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.1904 - accuracy: 0.6077 - val_loss: 1.5276 - val_accuracy: 0.5081
# Epoch 6/45
# 198/198 [==============================] - 33s 167ms/step - loss: 1.0751 - accuracy: 0.6465 - val_loss: 1.6300 - val_accuracy: 0.5162
# Epoch 7/45
# 198/198 [==============================] - 33s 167ms/step - loss: 0.9821 - accuracy: 0.6828 - val_loss: 1.5324 - val_accuracy: 0.5758
# Epoch 8/45
# 198/198 [==============================] - 35s 175ms/step - loss: 0.9012 - accuracy: 0.7102 - val_loss: 1.6667 - val_accuracy: 0.5740
# Epoch 9/45
# 198/198 [==============================] - 35s 175ms/step - loss: 0.8628 - accuracy: 0.7225 - val_loss: 1.6214 - val_accuracy: 0.5785
# Epoch 10/45
# 198/198 [==============================] - 33s 168ms/step - loss: 0.7553 - accuracy: 0.7602 - val_loss: 1.9014 - val_accuracy: 0.5379
# Epoch 11/45
#  22/198 [==>...........................] - ETA: 26s - loss: 0.7196 - accuracy: 0.7642
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 history_cnn_3_g = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(160, 120, 3), 
                  kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))
model3.add(Dropout(0.2))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.3))

model3.add(BatchNormalization())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.6))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_h = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 36s 182ms/step - loss: 1.9013 - accuracy: 0.3548 - val_loss: 1.7143 - val_accuracy: 0.4919
# Epoch 2/45
# 198/198 [==============================] - 38s 194ms/step - loss: 1.3162 - accuracy: 0.5698 - val_loss: 1.4488 - val_accuracy: 0.4928
# Epoch 3/45
# 198/198 [==============================] - 34s 170ms/step - loss: 1.1077 - accuracy: 0.6475 - val_loss: 1.4345 - val_accuracy: 0.5235
# Epoch 4/45
# 198/198 [==============================] - 33s 167ms/step - loss: 0.8663 - accuracy: 0.7325 - val_loss: 1.6037 - val_accuracy: 0.5289
# Epoch 5/45
# 198/198 [==============================] - 33s 168ms/step - loss: 0.7346 - accuracy: 0.7754 - val_loss: 1.5858 - val_accuracy: 0.6065
# Epoch 6/45
# 198/198 [==============================] - 34s 169ms/step - loss: 0.6334 - accuracy: 0.8103 - val_loss: 1.3498 - val_accuracy: 0.5731
# Epoch 7/45
# 198/198 [==============================] - 34s 169ms/step - loss: 0.5309 - accuracy: 0.8440 - val_loss: 1.4923 - val_accuracy: 0.5758
# Epoch 8/45
#  11/198 [>.............................] - ETA: 27s - loss: 0.4260 - accuracy: 0.8835
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 history_cnn_3_h = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(160, 120, 3), 
                  kernel_regularizer = l2(5e-4) ))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(8e-4) ))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.1))

model3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer = l2(5e-2) ))
model3.add(Dropout(0.2))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.4))

model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.7))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3_i = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 33s 163ms/step - loss: 2.6182 - accuracy: 0.2106 - val_loss: 1.9564 - val_accuracy: 0.2879
# Epoch 2/45
# 198/198 [==============================] - 32s 160ms/step - loss: 1.8165 - accuracy: 0.3676 - val_loss: 1.6236 - val_accuracy: 0.4070
# Epoch 3/45
# 198/198 [==============================] - 32s 161ms/step - loss: 1.5383 - accuracy: 0.4604 - val_loss: 1.5656 - val_accuracy: 0.4522
# Epoch 4/45
# 198/198 [==============================] - 33s 164ms/step - loss: 1.3750 - accuracy: 0.5440 - val_loss: 1.4984 - val_accuracy: 0.5208
# Epoch 5/45
# 198/198 [==============================] - 33s 166ms/step - loss: 1.2642 - accuracy: 0.5874 - val_loss: 1.4008 - val_accuracy: 0.5424
# Epoch 6/45
# 198/198 [==============================] - 32s 161ms/step - loss: 1.1577 - accuracy: 0.6213 - val_loss: 1.4323 - val_accuracy: 0.5812
# Epoch 7/45
# 198/198 [==============================] - 32s 161ms/step - loss: 1.0942 - accuracy: 0.6541 - val_loss: 1.4585 - val_accuracy: 0.5623
# Epoch 8/45
# 198/198 [==============================] - 33s 168ms/step - loss: 1.0237 - accuracy: 0.6831 - val_loss: 1.4263 - val_accuracy: 0.5912
# Epoch 9/45
# 198/198 [==============================] - 33s 165ms/step - loss: 0.9517 - accuracy: 0.7049 - val_loss: 1.6055 - val_accuracy: 0.5767
# Epoch 10/45
# 198/198 [==============================] - 32s 163ms/step - loss: 0.9312 - accuracy: 0.7170 - val_loss: 1.4299 - val_accuracy: 0.5785
# Epoch 11/45
# 198/198 [==============================] - 32s 160ms/step - loss: 0.8579 - accuracy: 0.7468 - val_loss: 1.4862 - val_accuracy: 0.5984
# Epoch 12/45
# 198/198 [==============================] - 32s 161ms/step - loss: 0.8325 - accuracy: 0.7531 - val_loss: 1.5336 - val_accuracy: 0.5839
# Epoch 13/45
# 198/198 [==============================] - 32s 162ms/step - loss: 0.7925 - accuracy: 0.7645 - val_loss: 1.6059 - val_accuracy: 0.6092
# Epoch 14/45
# 198/198 [==============================] - 34s 172ms/step - loss: 0.7558 - accuracy: 0.7770 - val_loss: 1.4720 - val_accuracy: 0.6137
# Epoch 15/45
# 198/198 [==============================] - 32s 163ms/step - loss: 0.7183 - accuracy: 0.7886 - val_loss: 1.8489 - val_accuracy: 0.5993
# Epoch 16/45
# 198/198 [==============================] - 32s 160ms/step - loss: 0.6872 - accuracy: 0.7963 - val_loss: 1.8575 - val_accuracy: 0.6038
# Epoch 17/45
# 198/198 [==============================] - 33s 166ms/step - loss: 0.6676 - accuracy: 0.8028 - val_loss: 1.6285 - val_accuracy: 0.6083
# Epoch 18/45
# 198/198 [==============================] - 32s 162ms/step - loss: 0.6322 - accuracy: 0.8199 - val_loss: 1.8132 - val_accuracy: 0.6029
# Epoch 19/45
# 198/198 [==============================] - 32s 161ms/step - loss: 0.6310 - accuracy: 0.8187 - val_loss: 2.0798 - val_accuracy: 0.5948

# %%
history_cnn_3_i = model3.fit(train_generator_3, validation_data = validation_generator_3, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
# 198/198 [==============================] - 36s 178ms/step - loss: 1.9451 - accuracy: 0.3027 - val_loss: 1.7173 - val_accuracy: 0.3755
# Epoch 2/45
# 198/198 [==============================] - 34s 169ms/step - loss: 1.3972 - accuracy: 0.5287 - val_loss: 1.5588 - val_accuracy: 0.4892
# Epoch 3/45
# 198/198 [==============================] - 33s 165ms/step - loss: 1.1188 - accuracy: 0.6341 - val_loss: 1.6794 - val_accuracy: 0.5794
# Epoch 4/45
# 198/198 [==============================] - 34s 173ms/step - loss: 0.9184 - accuracy: 0.7070 - val_loss: 1.7889 - val_accuracy: 0.5984
# Epoch 5/45
# 198/198 [==============================] - 34s 171ms/step - loss: 0.7728 - accuracy: 0.7650 - val_loss: 1.8115 - val_accuracy: 0.5921
# Epoch 6/45
# 198/198 [==============================] - 33s 165ms/step - loss: 0.6390 - accuracy: 0.8055 - val_loss: 2.0427 - val_accuracy: 0.5767
# Epoch 7/45
# 198/198 [==============================] - 34s 169ms/step - loss: 0.5251 - accuracy: 0.8378 - val_loss: 2.3599 - val_accuracy: 0.6011
# Epoch 8/45
# 154/198 [======================>.......] - ETA: 6s - loss: 0.4743 - accuracy: 0.8675
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 history_cnn_3_i = model3.fit(train_generator_3, validation_data = validation_generator_3,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model2 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model2.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))
model2.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.1))

model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.25))

# transition to dense fully-connected part of network
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.25))

model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))

model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

history_cnn_2 = model2.fit(train_generator_1, validation_data = validation_generator_1, 
                           epochs = 45, callbacks=[custom_early_stopping])

# %%
model3 = Sequential()

# define 3x3 filter window sizes. Create 32 filters.
model3.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(160, 120, 3)))
model3.add(MaxPooling2D(pool_size=(2, 2)))

# define 3x3 filter window sizes. Create 64 filters.
model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(MaxPooling2D((2, 2)))

model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(Dropout(0.25))
model3.add(MaxPooling2D((2, 2)))

# transition to dense fully-connected part of network
model3.add(Flatten())
model3.add(Dense(128, activation='relu'))
model3.add(Dropout(0.5))

model3.add(BatchNormalization())
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.6))

model3.add(Dense(10, activation='softmax'))

model3.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn_3 = model3.fit(train_generator_1, validation_data = validation_generator_1, 
                           epochs = 45, callbacks=[custom_early_stopping])
# Out:
# Epoch 1/45
#  78/198 [==========>...................] - ETA: 20s - loss: 0.4981 - accuracy: 0.8476
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 history_cnn_3 = model1.fit(train_generator_1, validation_data = validation_generator_1,
#       2                            epochs = 45, callbacks=[custom_early_stopping])
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/anaconda3/envs/Number41/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
