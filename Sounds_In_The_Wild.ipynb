# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense # creates densely connected layer object
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array

from tensorflow import keras
from tensorflow.keras import datasets, layers, models

from tensorflow.keras.layers import Conv2D # convolution layer
from tensorflow.keras.layers import MaxPooling2D # max pooling layer

from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

from keras.preprocessing.image import ImageDataGenerator

from keras.models import load_model
import pickle

# %%
model6 = load_model('CNN_Models/cnn_model_6.h5')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.ioff();

import os

import scipy 
from scipy.stats import norm

import math


import librosa
import librosa.display

from IPython.display import Audio

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import scale, LabelEncoder, StandardScaler, minmax_scale

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold3/177742-0-0-178.wav')

y = np.resize(y, 88200)

fig, ax = plt.subplots(figsize=(10,6), nrows = 2)

S = librosa.feature.melspectrogram(y=y, sr=sr)
img = librosa.display.specshow(librosa.power_to_db(S, ref=np.max), ax = ax[0])

y, sr = librosa.load('Source/UrbanSound8K/audio/fold9/189988-0-0-5.wav')

y = np.resize(y, 88200)


S = librosa.feature.melspectrogram(y=y, sr=sr)
img = librosa.display.specshow(librosa.power_to_db(S, ref=np.max), ax = ax[1])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.ioff();

import os

import scipy 
from scipy.stats import norm

import math


import librosa
import librosa.display

from IPython.display import Audio

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import scale, LabelEncoder, StandardScaler, minmax_scale

# %%
files_list = []
for i in os.listdir('./my_recordings'):
    files_list.append(i)

# %%
files_list = sorted(files_list)

# %%
files_list = files_list[2:]

# %%
    path = 'my_recordings/Street music_1.wav'
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    fig, ax = plt.subplots(figsize = (14,8))
    
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log')
    plt.show()

# %%
path = 'my_recordings/Street music_1.wav'
y, sr = librosa.load(path)
    
# Standardize the length to 88,200 samples, or 4 seconds
fig, ax = plt.subplots(figsize = (14,8))
    
    
S = librosa.feature.melspectrogram(y=y, sr=sr,)
S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log')
plt.title('Street Music Spectogram \n Mel Scale Y - Axis ', fontsize = 18)
plt.xlabel('Time in Seconds', fontsize=16)
plt.ylabel('Hz', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %%
path = 'my_recordings/Engine_1.wav'
y, sr = librosa.load(path)
    
# Standardize the length to 88,200 samples, or 4 seconds
fig, ax = plt.subplots(figsize = (14,8))
    
    
S = librosa.feature.melspectrogram(y=y, sr=sr,)
S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log')
plt.title('Engine Spectogram \n Mel Scale Y - Axis ', fontsize = 18)
plt.xlabel('Time in Seconds', fontsize=16)
plt.ylabel('Hz', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %%
path = 'my_recordings/Engine_1.wav'
y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
if y.shape != (88200,):
    y = np.resize(y, 88200)
        
fig, ax = plt.subplots(figsize = (14,8))
M = librosa.feature.melspectrogram(y=y, sr=sr)
M_db = librosa.power_to_db(M, ref=np.max)
img = librosa.display.specshow(M_db, y_axis='mel', x_axis='time', ax=ax)
plt.title('Dog Bark Mel Spectogram \n Mel Scale Y - Axis  ', fontsize = 18)
plt.xlabel('Time in Seconds', fontsize=16)
plt.ylabel('Hz', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %%
path = 'my_recordings/Street music_1.wav'
y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
if y.shape != (88200,):
    y = np.resize(y, 88200)
        
fig, ax = plt.subplots(figsize = (14,8))
M = librosa.feature.melspectrogram(y=y, sr=sr)
M_db = librosa.power_to_db(M, ref=np.max)
img = librosa.display.specshow(M_db, y_axis='mel', x_axis='time', ax=ax)
plt.title('Dog Bark Mel Spectogram \n Mel Scale Y - Axis  ', fontsize = 18)
plt.xlabel('Time in Seconds', fontsize=16)
plt.ylabel('Hz', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %%
files_list
# Out:
# ['Air_conditioner_1.wav',
#  'Air_conditioner_2.wav',
#  'Air_conditioner_3.wav',
#  'Engine_1.wav',
#  'Engine_2.wav',
#  'Engine_3.wav',
#  'Engine_4.wav',
#  'Street music_1.wav',
#  'Street music_2.wav',
#  'Street music_3.wav']

# %%
    path = 'my_recordings/{}'.format(

# %%
for i in range(len(files_list)):
    path = 'my_recordings/{}'.format(files_list[i])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    fig, axs = plt.subplots()
    
    axs[i].set_title(files_list[i])
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 10
#       7     y = np.resize(y, 88200)
#       8 fig, axs = plt.subplots()
# ---> 10 axs[i].set_title(files_list[i])
#      12 S = librosa.feature.melspectrogram(y=y, sr=sr,)
#      13 S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
#
# TypeError: 'Axes' object is not subscriptable

# %%
plt.show()

# %%
# Saving Recording Images

for file in files_list:
    path = 'my_recordings/{}'.format(file)
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = file[:-4]

    file_path = 'recordings/'
    
    if not os.path.isdir(my_path + file_path):
        os.makedirs(my_path + file_path)
        
    plt.savefig(my_path + file_path + file_name)
    
    plt.close()

# %%
# Save train spectograms

for idx, row in test_meta_data.iterrows():
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    testing_path = 'test_images/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + testing_path):
        os.makedirs(my_path + testing_path)
        
    plt.savefig(my_path + testing_path + file_name)
    
    plt.close()
