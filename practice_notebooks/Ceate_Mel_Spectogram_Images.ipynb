# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os

import math

import librosa
import librosa.display

import IPython

from IPython.display import Audio

from sklearn.model_selection import train_test_split

# %%
plt.ioff();

# %%
meta_data = pd.read_csv('Source/UrbanSound8K/metadata/UrbanSound8K.csv')

# %%
meta_data.sample(30)
# Out:
#         slice_file_name    fsID       start         end  salience  fold  \
# 1044   123688-8-1-1.wav  123688   56.544659   60.544659         1     2
# 6763    54823-3-2-1.wav   54823   20.319143   24.319143         1     9
# 7766   74507-0-0-28.wav   74507   14.000000   18.000000         1     2
# 248   103258-5-0-19.wav  103258    9.500000   13.500000         1     1
# 4573    18594-1-1-0.wav   18594   12.833291   13.464541         1     3
# 5849   24347-8-0-96.wav   24347   52.120371   56.120371         2     4
# 4120  178826-2-0-28.wav  178826   14.000000   18.000000         1    10
# 1824   145683-6-5-0.wav  145683   26.109938   26.612052         2     9
# 8248    83502-0-0-5.wav   83502    2.500000    6.500000         2    10
# 8390    90014-8-0-0.wav   90014    0.000000    4.000000         1     3
# 5602   22601-8-0-22.wav   22601   11.000000   15.000000         2     3
# 3444  171165-9-0-54.wav  171165   27.000000   31.000000         1     7
# 2406   156869-8-0-5.wav  156869    7.150289   11.150289         1     5
# 7572    72265-3-5-0.wav   72265   37.130049   40.226654         2     9
# 6264    37869-3-1-0.wav   37869    6.003142    7.414477         1     5
# 2369   156418-3-1-0.wav  156418    8.434880   12.434880         1     3
# 2366   156362-4-3-8.wav  156362  313.117912  317.117912         2     4
# 6025   30206-7-0-21.wav   30206   10.500000   14.500000         1     6
# 5264   203355-3-0-0.wav  203355   42.985765   44.114000         2     6
# 6583  49485-9-0-142.wav   49485   73.247790   77.247790         1     3
# 1745   144068-5-4-8.wav  144068  120.444222  124.444222         1     3
# 7549    72259-1-9-1.wav   72259  224.938833  228.938833         2     5
# 2912  162134-7-11-4.wav  162134  194.102215  198.102215         1    10
# 5865    24364-4-0-9.wav   24364    5.133371    9.133371         1     6
# 7043   61789-9-0-12.wav   61789    6.000000   10.000000         1     7
# 4626   187356-1-5-0.wav  187356   64.428190   67.045729         2     4
# 5992    29936-3-3-0.wav   29936   16.941228   19.022853         2     8
# 8631    98223-7-5-0.wav   98223   36.232035   38.457894         1     1
# 1668   14387-9-0-11.wav   14387    5.500000    9.500000         1     2
# 7681     7389-1-3-5.wav    7389   98.609623  102.609623         2     4
#
#       classID             class
# 1044        8             siren
# 6763        3          dog_bark
# 7766        0   air_conditioner
# 248         5     engine_idling
# 4573        1          car_horn
# 5849        8             siren
# 4120        2  children_playing
# 1824        6          gun_shot
# 8248        0   air_conditioner
# 8390        8             siren
# 5602        8             siren
# 3444        9      street_music
# 2406        8             siren
# 7572        3          dog_bark
# 6264        3          dog_bark
# 2369        3          dog_bark
# 2366        4          drilling
# 6025        7        jackhammer
# 5264        3          dog_bark
# 6583        9      street_music
# 1745        5     engine_idling
# 7549        1          car_horn
# 2912        7        jackhammer
# 5865        4          drilling
# 7043        9      street_music
# 4626        1          car_horn
# 5992        3          dog_bark
# 8631        7        jackhammer
# 1668        9      street_music
# 7681        1          car_horn

# %%
meta_data
y, sr = librosa.load('Source/UrbanSound8K/audio/fold5/100263-2-0-117.wav')

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold5/100263-2-0-117.wav')

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold2/74507-0-0-28.wav')

fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
img = librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

ax.set_title('Librosa generated spectrogram:')
plt.colorbar(img)

plt.show()

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
img = librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

ax.set_title('Librosa generated spectrogram:')
plt.colorbar(img)
plt.show()

# %%
RMS=math.sqrt(np.mean(y**2))

# %%
RMS*.1

# %%
noise= (np.random.normal(0, RMS*.1, y.shape[0]))

# %%
noise

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(noise)
plt.show()

# %%
signal_with_noise = y+noise
plt.plot(signal_with_noise)
plt.show()

# %%
Audio(signal_with_noise, rate=sr)

# %%
sparse_noise = np.linspace(0,0, 88200)

# %%
for x  in np.arange(0,88200, 50):
    sparse_noise[x] = noise[x]

# %%
sparse_noise

# %%
plt.plot(list_noise)
plt.show()

# %%
import cmath

# %%
signal_noise = y+list_noise

# %%
y.mean()

# %%
y.std()

# %%
sparse_signal_noise = y + sparse_noise

# %%
plt.plot(y[0:500])
plt.show();

# %%
plt.plot(sparse_signal_noise[0:500])
plt.show()

# %%
Audio(sparse_signal_noise, rate=sr)

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,)

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(signal_with_noise)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,)

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(sparse_signal_noise)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,)

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
    fig, ax = plt.subplots()
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.show()

# %%
    fig, ax = plt.subplots()
    S = librosa.feature.melspectrogram(y=sparse_signal_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
librosa.display.waveshow(y, sr=sr, ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Matplotlib generated spectrogram:')
ax.specgram(y, cmap='gist_gray');
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,6), nrows=2)

ax[0].set_title('Matplotlib generated spectrogram:')
ax[0].specgram(y, cmap='Pastel1');
ax[0].axis('off');

x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax[1],)

ax[1].set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
8732*.75

# %%
8732*.85

# %%
8732*.15

# %%
meta_data['class'].value_counts()

# %%
# Save training data spectograms

for idx, row in train_meta_data.iterrows():
    
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    
    # Create Matplotlib Image
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    
    # Save the Spectogram Image
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'mel_train/{}/'.format(row['classID'])
        
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name)
    
    plt.close()

# %%
# Save training data spectograms

for idx, row in test_meta_data.iterrows():
    
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    
    # Create Matplotlib Image
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    
    # Save the Spectogram Image
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    testing_path = 'mel_test/{}/'.format(row['classID'])
        
    if not os.path.isdir(my_path + testing_path):
        os.makedirs(my_path + testing_path)
        
    plt.savefig(my_path + testing_path + file_name)
    
    plt.close()

# %%
train_meta_data.head(40)

# %%
meta_data[meta_data['slice_file_name'] == '77751-4-1-0.wav']

# %%
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(2,'77751-4-1-0.wav')
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    D = librosa.stft(y)  # Short Time Fourier Transform (STFT) of y
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
    img = librosa.display.specshow(S_db, x_axis='time' , y_axis='linear', ax = ax)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Plotting Spectogram as Logged Y-Axis

# %%
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(2,'77751-4-1-0.wav')
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    D = librosa.stft(y)  # Short Time Fourier Transform (STFT) of y
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
    img = librosa.display.specshow(S_db, x_axis='time' , y_axis='linear', ax = ax)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Plotting Mel-Spectogram Logged Y-Axis

# %%
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(2,'77751-4-1-0.wav')
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)


    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')
    plt.show()

# %%
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(1,'180937-7-3-0.wav')
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)


    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')
    plt.show()

# %%
meta_data[meta_data['slice_file_name'] == '98223-7-0-0.wav']

# %%
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(1,'98223-7-0-0.wav')
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)


    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)#, cmap_div='coolwarm')
    #librosa.display.cmap(S_db_mel)
    plt.show()

# %%
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(1,'98223-7-0-0.wav')
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()

    sgram_mag, _ = librosa.magphase(S)

    mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sr)
#librosa.display.specshow(mel_scale_sgram)


# use the decibel scale to get the final Mel Spectrogram

    mel_sgram = librosa.amplitude_to_db(mel_scale_sgram, ref=np.min)
    librosa.display.specshow(mel_sgram, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.show()

# %% [markdown]
# ### Previous Spectogram Function (Linear Spectograms)

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'],
                                                                                         row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()
    
    D = librosa.stft(y)  # Short Time Fourier Transform (STFT) of y
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
    img = librosa.display.specshow(S_db, ax = ax)
    
    my_path = 'Source/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'mel_train/{}/'.format(row['classID'])
        
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name)
    
    plt.close()

# %%
# Save test spectograms

for idx, row in test_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'],
                                                                                         row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)

    
    fig, ax = plt.subplots()
    
    D = librosa.stft(y)  # Short Time Fourier Transform (STFT) of y
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
    img = librosa.display.specshow(S_db, ax = ax)
    
    my_path = 'Source/'
    file_name = row['slice_file_name'][:-4]
    
    testing_path = 'mel_test/{}/'.format(row['classID'])
        
    if not os.path.isdir(my_path + testing_path):
        os.makedirs(my_path + testing_path)
        
    plt.savefig(my_path + testing_path + file_name)

    plt.close()

# %%
street_music_children = ['street_music', 'children_playing']

# %%
meta_data['class'].value_counts()

# %%
meta_data

# %%
street_music = meta_data[meta_data['class'] == 'street_music']
children = meta_data[meta_data['class'] == 'children_playing']

# %% [markdown]
# Children Playing vs Street Music

# %% [markdown]
# Children_Playing Spectograms

# %%
children.head(10)

# %%
children_background = children[children['salience'] == 2]

# %%
def linear_spects(df, samples):
    
    for idx, row in df[:samples].iterrows():
        path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
        y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
        if y.shape != (88200,):
            y = np.resize(y, 88200)
    
        fig, ax = plt.subplots()
    
        D = librosa.stft(y)  # Short Time Fourier Transform (STFT) of y
        S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
        img = librosa.display.specshow(S_db, x_axis='time' , y_axis='linear', ax = ax)
    
        ax.set(title = 'Y Linear- Class: {} Salience: {} \n Fold #: {} Audio File: {}'
           .format(row['class'], row['salience'], row['fold'], row['slice_file_name']))

    return plt.show()

# %%
def log_spects(df,samples):
    
    for idx, row in df[:samples].iterrows():
        path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
        y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
        if y.shape != (88200,):
            y = np.resize(y, 88200)
    
        fig, ax = plt.subplots()
    
        D = librosa.stft(y)  # Short Time Fourier Transform (STFT) of y
        S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
        img = librosa.display.specshow(S_db, x_axis='time' , y_axis='log', ax = ax)
    
        ax.set(title = 'Y Log- Class: {} Salience: {} \n Fold #: {} Audio File: {}'
           .format(row['class'], row['salience'], row['fold'], row['slice_file_name']))

    return plt.show()

# %%
def mel_spects(df,samples):
    
    for idx, row in df[:samples].iterrows():
        path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
        y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
        if y.shape != (88200,):
            y = np.resize(y, 88200)
            
        S = librosa.feature.melspectrogram(y=y, sr=sr)
        S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
        
        fig, ax = plt.subplots()   
        
        img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    
        ax.set(title = 'Mel Spectogram- Class: {} Salience: {} \n Fold #: {} Audio File: {}'
           .format(row['class'], row['salience'], row['fold'], row['slice_file_name']))

    return plt.show()

# %%
def mel_spects_magphase(df, samples):
    
    for idx, row in df[:samples].iterrows():
        path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
        y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
        if y.shape != (88200,):
            y = np.resize(y, 88200)
            
        S = librosa.feature.melspectrogram(y=y, sr=sr)
        
        sgram_mag, _ = librosa.magphase(S)
        
        mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sr)

        
        
        fig, ax = plt.subplots()  
        
        mel_sgram = librosa.amplitude_to_db(mel_scale_sgram, ref=np.min)
        img = librosa.display.specshow(mel_sgram, sr=sr, x_axis='time', y_axis='mel', ax = ax)
    
        ax.set(title = 'Mel Spectogram- Class: {} Salience: {} \n Fold #: {} Audio File: {}'
           .format(row['class'], row['salience'], row['fold'], row['slice_file_name']))

    return plt.show()

# %%
mel_spects(children, 5)

# %%
mel_spects(street_music, 5)

# %%
mel_spects_magphase(children, 5)

# %%
mel_spects(street_music_background, 5)

# %%
mel_spects_magphase(street_music_background, 5)

# %%
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    fig, ax = plt.subplots()

    sgram_mag, _ = librosa.magphase(S)

    mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr=sr)
#librosa.display.specshow(mel_scale_sgram)


# use the decibel scale to get the final Mel Spectrogram

    mel_sgram = librosa.amplitude_to_db(mel_scale_sgram, ref=np.min)
    librosa.display.specshow(mel_sgram, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.show()

# %%
mel_spects(children, 5)

# %%
mel_spects(children_background, 5)

# %%
mel_spects(street_music_background, 5)

# %%
Audio('Source/UrbanSound8K/audio/fold4/107653-9-0-18.wav')

# %%
Audio('Source/UrbanSound8K/audio/fold4/107653-9-0-3.wav')

# %%
street_music.head(10)

# %%
street_music_background = street_music[street_music['salience'] == 2]

# %%
street_music_background

# %% [markdown]
# Drilling vs Jackhammer

# %% [markdown]
# Street Music

# %% [markdown]
# Air Conditioner

# %% [markdown]
# Air Conditioner vs Engine Idling

# %%
Train 85
Validation 65
Test 75 or 80

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold5/100263-2-0-117.wav')

Audio(y, rate=sr)

RMS=math.sqrt(np.mean(y**2))
noise= (np.random.normal(0, y.std(), y.shape[0]))/2
sparse_noise = np.linspace(0,0, 88200)
for x  in np.arange(0,88200, 50):
    sparse_noise[x] = noise[x]
sparse_noise

# %%
train_meta_data, test_meta_data = train_test_split(meta_data, test_size=0.15\
                                                   ,random_state=42, stratify=meta_data['classID'])

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    RMS=math.sqrt(np.mean(y**2))
    noise= (np.random.normal(0, RMS*.05, y.shape[0]))
    signal_with_noise = y + noise
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=signal_with_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'mel_train_and_some_noise/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_2')
    
    plt.close()

# %%
# Save test spectograms

for idx, row in test_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'],
                                                                                         row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)

    RMS=math.sqrt(np.mean(y**2))
    noise= (np.random.normal(0, y.std(), y.shape[0]))/2
    sparse_noise = np.linspace(0,0, 88200)
    for x in np.arange(0,88200, 50):
        sparse_noise[x] = noise[x]
    sparse_noise
    sparse_signal_noise = y + sparse_noise
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=sparse_signal_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Source/'
    file_name = row['slice_file_name'][:-4]
    
    testing_path = 'mel_test/{}/'.format(row['classID'])
        
    if not os.path.isdir(my_path + testing_path):
        os.makedirs(my_path + testing_path)
        
    plt.savefig(my_path + testing_path + file_name)

    plt.close()

# %%
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=sparse_signal_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    plt.show()

# %% [markdown]
# Create Log STFT Spectograms and add noise to train data

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

fig.tight_layout()
plt.axis('off')    

plt.show()

# %%
meta_data.sample(15)

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold3/195451-5-0-12.wav')
fig, ax = plt.subplots()
x_stft = librosa.stft(y)

    
RMS=math.sqrt(np.mean(y**2))
noise= (np.random.normal(0, RMS*.2, y.shape[0]))
signal_with_noise = y + noise

ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

fig.tight_layout()
plt.axis('off')    

plt.show()

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    RMS=math.sqrt(np.mean(y**2))
    noise= (np.random.normal(0, RMS*.2, y.shape[0]))
    signal_with_noise = y + noise
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=signal_with_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'mel_train_and_some_noise/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_2')
    
    plt.close()

# %%
def new_mel_spects(fold_num, file_name, class_type, salience):
    fig, ax = plt.subplots()
    y, sr = librosa.load('Source/UrbanSound8K/audio/fold{}/{}'.format(fold_num, file_name))
    if y.shape != (88200,):
        y = np.resize(y, 88200)
        
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
    S_dB = librosa.power_to_db(S, ref=np.max)
    img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr,fmax=8000, ax=ax)

    ax.set(title = 'Mel Spectogram- Class: {} Salience: {}'
           .format(class_type, salience))

    plt.show()

# %%
meta_data.sample(40)

# %%
    y, sr = librosa.load('Source/UrbanSound8K/audio/fold10/39847-5-0-8.wav')
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,n_mels=128, fmax=8000)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    plt.show()

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold5/178260-7-1-4.wav')
    
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
y, sr = librosa.load('Source/UrbanSound8K/audio/fold5/178260-7-1-4.wav')
fig, ax = plt.subplots()
    
S = librosa.feature.melspectrogram(y=y, sr=sr,n_mels=128, fmax=8000)
S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
plt.axis('off')    
plt.show()

# %%
new_mel_spects(5, '100263-2-0-117.wav', 'dog_bark', 1)

# %%
new_mel_spects(7, '99812-1-2-0.wav', 'car_horn',2)

# %%
13230-0-0-5.wav	,

# %%
train_meta_data, test_meta_data = train_test_split(meta_data, test_size=0.15\
                                                   ,random_state=42, stratify=meta_data['classID'])

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y= y , sr= sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'train_mel_spect_and_noise/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_2')
    
    plt.close()

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    RMS=math.sqrt(np.mean(y**2))
    noise= (np.random.normal(0, RMS*.1, y.shape[0]))
    signal_with_noise = y + noise
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=signal_with_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'train_mel_spect_and_noise/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_2')
    
    plt.close()

# %% [markdown]
# Regular Log Spectograms

# %%
fig, ax = plt.subplots()
x_stft = librosa.stft(y)
ampl = librosa.amplitude_to_db(abs(x_stft))
librosa.display.specshow(ampl, ax=ax,x_axis='time' , y_axis='log')

ax.set_title('Librosa generated spectrogram:')
fig.tight_layout()
plt.show()

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
        
    fig, ax = plt.subplots()
    
    RMS = math.sqrt(np.mean(y**2))
    noise = (np.random.normal(0, RMS*.1, y.shape[0]))
    signal_with_noise = y + noise

    x_stft = librosa.stft(signal_with_noise)
    ampl = librosa.amplitude_to_db(abs(x_stft))
    librosa.display.specshow(ampl, ax=ax, x_axis='time' , y_axis='log')
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'train_log_spectograms/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_2')
    
    plt.close()

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    fig, ax = plt.subplots()
    
    x_stft = librosa.stft(y)
    ampl = librosa.amplitude_to_db(abs(x_stft))
    librosa.display.specshow(ampl, ax=ax, x_axis='time' , y_axis='log')
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]
    training_path = 'train_log_spectograms/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_noise')
    
    plt.close()

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
        
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'train_mel_spect_and_noise/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name)
    
    plt.close()

# %%
# Save train spectograms

for idx, row in train_meta_data.iterrows():
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    RMS=math.sqrt(np.mean(y**2))
    noise= (np.random.normal(0, RMS*.1, y.shape[0]))
    signal_with_noise = y + noise
    
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=signal_with_noise, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    training_path = 'train_mel_spect_and_noise/{}/'.format(row['classID'])
    
    if not os.path.isdir(my_path + training_path):
        os.makedirs(my_path + training_path)
        
    plt.savefig(my_path + training_path + file_name + '_2')
    
    plt.close()

# %%
test_meta_data
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 1583   138473-9-0-12.wav  138473    7.523034   11.523034         2     3
# 4924  194458-9-1-122.wav  194458  163.261507  167.261507         2     4
# 49      100852-0-0-6.wav  100852    3.000000    7.000000         1     5
# 5441    204773-3-9-0.wav  204773   42.184968   46.184968         1     2
# 6753     54545-3-0-0.wav   54545    0.826371    4.826371         1     2
# ...                  ...     ...         ...         ...       ...   ...
# 3421    170022-0-0-0.wav  170022    9.042850   13.042850         1     8
# 6638     50661-5-0-3.wav   50661    1.500000    5.500000         1     4
# 6747     54383-0-0-4.wav   54383    2.000000    6.000000         1     8
# 2883    162103-0-0-1.wav  162103    0.500000    4.500000         1     8
# 6401      4201-3-0-0.wav    4201    0.104715    0.352725         2     2
#
#       classID            class
# 1583        9     street_music
# 4924        9     street_music
# 49          0  air_conditioner
# 5441        3         dog_bark
# 6753        3         dog_bark
# ...       ...              ...
# 3421        0  air_conditioner
# 6638        5    engine_idling
# 6747        0  air_conditioner
# 2883        0  air_conditioner
# 6401        3         dog_bark
#
# [1310 rows x 8 columns]

# %%
# Save training data spectograms

for idx, row in test_meta_data.iterrows():
    
    path = 'Source/UrbanSound8K/audio/fold{}/{}'.format(row['fold'], row['slice_file_name'])
    
    y, sr = librosa.load(path)
    
    # Standardize the length to 88,200 samples, or 4 seconds
    if y.shape != (88200,):
        y = np.resize(y, 88200)
    
    
    # Create Matplotlib Image
    fig, ax = plt.subplots()
    
    S = librosa.feature.melspectrogram(y=y, sr=sr,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    
    img = librosa.display.specshow(S_db_mel, x_axis='time' , y_axis='log', ax = ax)
    plt.axis('off')    
    
    # Save the Spectogram Image
    my_path = 'Data/'
    file_name = row['slice_file_name'][:-4]

    testing_path = 'test_mel_spect/{}/'.format(row['classID'])
        
    if not os.path.isdir(my_path + testing_path):
        os.makedirs(my_path + testing_path)
        
    plt.savefig(my_path + testing_path + file_name)
    
    plt.close()
